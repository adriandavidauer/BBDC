# %%
import pandas as pd

test = pd.read_csv("C:/Users/13udha/Downloads/train.csv")    
test.head()
# Out:
#                  Datum  Windgeschwindigkeit48M  Windgeschwindigkeit100M  \
# 0  2016-01-01 00:00:00                   8.490                  10.7700
# 1  2016-01-01 00:15:00                   8.395                  10.6175
# 2  2016-01-01 00:30:00                   8.300                  10.4650
# 3  2016-01-01 00:45:00                   8.205                  10.3125
# 4  2016-01-01 01:00:00                   8.110                  10.1600
#
#    Windgeschwindigkeit152M  Windrichtung48M  Windrichtung100M  \
# 0                   12.690           188.00             190.0
# 1                   12.475           190.75             193.0
# 2                   12.260           193.50             196.0
# 3                   12.045           196.25             199.0
# 4                   11.830           199.00             202.0
#
#    Windrichtung152M  Windgeschwindigkeit100MP10  Windgeschwindigkeit100MP20  \
# 0            194.00                      9.0700                       9.630
# 1            196.75                      9.0425                       9.555
# 2            199.50                      9.0150                       9.480
# 3            202.25                      8.9875                       9.405
# 4            205.00                      8.9600                       9.330
#
#    Windgeschwindigkeit100MP30  Windgeschwindigkeit100MP40  \
# 0                      10.060                       10.43
# 1                       9.955                       10.31
# 2                       9.850                       10.19
# 3                       9.745                       10.07
# 4                       9.640                        9.95
#
#    Windgeschwindigkeit100MP50  Windgeschwindigkeit100MP60  \
# 0                       10.78                     11.0500
# 1                       10.63                     10.9275
# 2                       10.48                     10.8050
# 3                       10.33                     10.6825
# 4                       10.18                     10.5600
#
#    Windgeschwindigkeit100MP70  Windgeschwindigkeit100MP80  \
# 0                     11.5400                      11.940
# 1                     11.3875                      11.815
# 2                     11.2350                      11.690
# 3                     11.0825                      11.565
# 4                     10.9300                      11.440
#
#    Windgeschwindigkeit100MP90  Interpoliert  Verfügbare_Kapazität  Output
# 0                     12.4200             0              122400.0   79168
# 1                     12.3125             1              122400.0   75124
# 2                     12.2050             1              122400.0   76072
# 3                     12.0975             1              122400.0   67964
# 4                     11.9900             0              122400.0   69988

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52508 entries, 0 to 52507
# Data columns (total 19 columns):
# Datum                         52508 non-null object
# Windgeschwindigkeit48M        52508 non-null float64
# Windgeschwindigkeit100M       52508 non-null float64
# Windgeschwindigkeit152M       52508 non-null float64
# Windrichtung48M               52508 non-null float64
# Windrichtung100M              52508 non-null float64
# Windrichtung152M              52508 non-null float64
# Windgeschwindigkeit100MP10    52508 non-null float64
# Windgeschwindigkeit100MP20    52508 non-null float64
# Windgeschwindigkeit100MP30    52508 non-null float64
# Windgeschwindigkeit100MP40    52508 non-null float64
# Windgeschwindigkeit100MP50    52508 non-null float64
# Windgeschwindigkeit100MP60    52508 non-null float64
# Windgeschwindigkeit100MP70    52508 non-null float64
# Windgeschwindigkeit100MP80    52508 non-null float64
# Windgeschwindigkeit100MP90    52508 non-null float64
# Interpoliert                  52508 non-null int64
# Verfügbare_Kapazität          52508 non-null float64
# Output                        52508 non-null int64
# dtypes: float64(16), int64(2), object(1)
# memory usage: 7.6+ MB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
test.hist(bins=50, figsize=(20,15))
plt.show()

# %%
import numpy as np
np.random.seed(420)
def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
train_set,test_set = split_train_test(test, 0.2)
print(len(train_set),"train + ",len(test_set),"test")
# Out:
# 42007 train +  10501 test

# %%
corr_matrix = test.corr()

# %%
corr_matrix["Output"].sort_values(ascending=False)
# Out:
# Output                        1.000000
# Windgeschwindigkeit48M        0.889447
# Windgeschwindigkeit100MP90    0.889284
# Windgeschwindigkeit100MP80    0.889191
# Windgeschwindigkeit100MP70    0.889053
# Windgeschwindigkeit100MP60    0.888947
# Windgeschwindigkeit100M       0.888803
# Windgeschwindigkeit100MP50    0.888798
# Windgeschwindigkeit100MP40    0.888227
# Windgeschwindigkeit100MP30    0.887776
# Windgeschwindigkeit100MP20    0.886977
# Windgeschwindigkeit100MP10    0.885870
# Windgeschwindigkeit152M       0.875016
# Windrichtung48M               0.117044
# Windrichtung100M              0.113851
# Windrichtung152M              0.111899
# Verfügbare_Kapazität          0.069501
# Interpoliert                  0.000244
# Name: Output, dtype: float64
